# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Read data

# %%
hydro = pd.read_csv("AKJCL_2000-01-01_2021-12-31.csv", engine='python')
hydro.head()
# Out:
#    S.N.        Date  Total Transactions  Total Traded Shares  \
# 0     1  2021-12-29                 293              44404.0
# 1     2  2021-12-28                 474              81741.0
# 2     3  2021-12-27                 660             118407.0
# 3     4  2021-12-26                 608             115254.0
# 4     5  2021-12-23                 819             128123.0
#
#    Total Traded Amount  Max. Price  Min. Price  Close Price
# 0           12159732.6       280.0       270.0        273.0
# 1           22254586.3       280.0       264.0        274.9
# 2           33305303.9       295.4       270.0        272.0
# 3           33393501.0       297.0       285.8        289.8
# 4           37791022.7       307.0       282.0        291.0

# %% [markdown]
# # Sort Data in Ascending Order

# %%
hydro = hydro.sort_values(by="Date")
hydro.head()
# Out:
#      S.N.        Date  Total Transactions  Total Traded Shares  \
# 670   671  2018-12-20                  75               1245.0
# 669   670  2018-12-23                 190               2920.0
# 668   669  2018-12-24                 142               2320.0
# 667   668  2018-12-25                  35                590.0
# 666   667  2018-12-26                  26                390.0
#
#      Total Traded Amount  Max. Price  Min. Price  Close Price
# 670             125345.0       138.0        86.0        102.0
# 669             295210.0       104.0        98.0        104.0
# 668             239350.0       106.0       100.0        102.0
# 667              58880.0       102.0        98.0        101.0
# 666              39490.0       102.0       100.0        101.0

# %% [markdown]
# # Handle Missing Data

# %%
hydro = hydro.dropna()
hydro.tail()
# Out:
#    S.N.        Date  Total Transactions  Total Traded Shares  \
# 4     5  2021-12-23                 819             128123.0
# 3     4  2021-12-26                 608             115254.0
# 2     3  2021-12-27                 660             118407.0
# 1     2  2021-12-28                 474              81741.0
# 0     1  2021-12-29                 293              44404.0
#
#    Total Traded Amount  Max. Price  Min. Price  Close Price
# 4           37791022.7       307.0       282.0        291.0
# 3           33393501.0       297.0       285.8        289.8
# 2           33305303.9       295.4       270.0        272.0
# 1           22254586.3       280.0       264.0        274.9
# 0           12159732.6       280.0       270.0        273.0

# %% [markdown]
# # Plot Trend

# %%
hydro.iplot(kind="line",x="Date",y="Close Price",xTitle="Date", yTitle="Close Price", title="Hydropower Trend")
# Out:
# <div>                            <div id="acfb9be3-ab36-4741-8e9c-9ce1e195e46e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("acfb9be3-ab36-4741-8e9c-9ce1e195e46e")) {                    Plotly.newPlot(                        "acfb9be3-ab36-4741-8e9c-9ce1e195e46e",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Close Price","text":"","x":["2018-12-20","2018-12-23","2018-12-24","2018-12-25","2018-12-26","2018-12-27","2018-12-30","2018-12-31","2019-01-01","2019-01-02","2019-01-03","2019-01-06","2019-01-07","2019-01-08","2019-01-09","2019-01-10","2019-01-13","2019-01-14","2019-01-15","2019-01-16","2019-01-17","2019-01-20","2019-01-21","2019-01-22","2019-01-23","2019-01-24","2019-01-27","2019-01-28","2019-01-29","2019-01-30","2019-01-31","2019-02-03","2019-02-04","2019-02-05","2019-02-06","2019-02-07","2019-02-10","2019-02-11","2019-02-12","2019-02-13","2019-02-14","2019-02-17","2019-02-18","2019-02-19","2019-02-20","2019-02-21","2019-02-24","2019-02-25","2019-02-26","2019-02-27","2019-03-03","2019-03-05","2019-03-06","2019-03-07","2019-03-10","2019-03-11","2019-03-12","2019-03-13","2019-03-14","2019-03-17","2019-03-18","2019-03-19","2019-03-21","2019-03-24","2019-03-25","2019-03-26","2019-03-27","2019-03-28","2019-03-31","2019-04-01","2019-04-02","2019-04-03","2019-04-04","2019-04-07","2019-04-08","2019-04-09","2019-04-10","2019-04-11","2019-04-15","2019-04-16","2019-04-17","2019-04-18","2019-04-21","2019-04-22","2019-04-23","2019-04-24","2019-04-25","2019-04-28","2019-04-29","2019-04-30","2019-05-02","2019-05-05","2019-05-06","2019-05-07","2019-05-08","2019-05-09","2019-05-12","2019-05-13","2019-05-14","2019-05-15","2019-05-16","2019-05-19","2019-05-20","2019-05-21","2019-05-22","2019-05-23","2019-05-26","2019-05-27","2019-05-28","2019-05-29","2019-05-30","2019-06-02","2019-06-03","2019-06-04","2019-06-06","2019-06-10","2019-06-11","2019-06-12","2019-06-13","2019-06-16","2019-06-17","2019-06-18","2019-06-19","2019-06-20","2019-06-23","2019-06-24","2019-06-25","2019-06-26","2019-06-27","2019-06-30","2019-07-01","2019-07-02","2019-07-03","2019-07-04","2019-07-07","2019-07-08","2019-07-09","2019-07-10","2019-07-11","2019-07-14","2019-07-15","2019-07-16","2019-07-17","2019-07-18","2019-07-21","2019-07-22","2019-07-23","2019-07-24","2019-07-25","2019-07-28","2019-07-29","2019-07-30","2019-07-31","2019-08-01","2019-08-04","2019-08-05","2019-08-06","2019-08-07","2019-08-08","2019-08-11","2019-08-12","2019-08-13","2019-08-14","2019-08-15","2019-08-18","2019-08-19","2019-08-20","2019-08-21","2019-08-22","2019-08-25","2019-08-26","2019-08-27","2019-08-28","2019-08-29","2019-09-01","2019-09-02","2019-09-03","2019-09-04","2019-09-05","2019-09-08","2019-09-09","2019-09-10","2019-09-10","2019-09-11","2019-09-12","2019-09-15","2019-09-16","2019-09-17","2019-09-18","2019-09-19","2019-09-22","2019-09-23","2019-09-24","2019-09-25","2019-09-26","2019-09-29","2019-09-30","2019-10-01","2019-10-02","2019-10-03","2019-10-10","2019-10-14","2019-10-15","2019-10-16","2019-10-17","2019-10-20","2019-10-21","2019-10-22","2019-10-23","2019-10-24","2019-10-31","2019-11-03","2019-11-04","2019-11-05","2019-11-06","2019-11-07","2019-11-10","2019-11-11","2019-11-12","2019-11-13","2019-11-14","2019-11-17","2019-11-18","2019-11-19","2019-11-20","2019-11-21","2019-11-24","2019-11-25","2019-11-26","2019-11-27","2019-11-28","2019-12-01","2019-12-02","2019-12-03","2019-12-04","2019-12-05","2019-12-08","2019-12-09","2019-12-10","2019-12-11","2019-12-12","2019-12-15","2019-12-17","2019-12-18","2019-12-19","2019-12-22","2019-12-23","2019-12-24","2019-12-25","2019-12-26","2019-12-29","2019-12-30","2019-12-31","2020-01-01","2020-01-02","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-12","2020-01-13","2020-01-14","2020-01-15","2020-01-16","2020-01-19","2020-01-20","2020-01-21","2020-01-22","2020-01-23","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020- ...

# %% [markdown]
# # Next Price

# %%
hydro['Next Price'] = hydro.shift(-1)['Close Price']

# %%
hydro = hydro.dropna()

# %% [markdown]
# # Rename Columns

# %%
hydro.columns
# Out:
# Index(['S.N.', 'Date', 'Total Transactions', 'Total Traded Shares',
#        'Total Traded Amount', 'Max. Price', 'Min. Price', 'Close Price',
#        'Next Price'],
#       dtype='object')

# %%
hydro.rename(columns = {'S.N.':'SN','Total Transactions':'TTrans', 'Total Traded Shares':'TTS',
                              'Total Traded Amount':'TTA','Close Price':'ClosePrice','Next Price':'NextPrice',
                     'Max. Price':'MaxPrice','Min. Price':'MinPrice'}, inplace = True)

# %% [markdown]
# # Prepared Features

# %%
features = ['ClosePrice',"Date"]
outFeature = ['NextPrice',"Date"]

# %%
# take close price as feature and next price as out feature
X, Y = insurance[features], insurance[outFeature] 
X.set_index("Date", inplace=True)
Y.set_index("Date", inplace=True)

# %% [markdown]
# # Normalize Data

# %%
#Normalize data using standard scalar.
ss = StandardScaler()

X["ClosePrice"] = ss.fit_transform(X)
Y["NextPrice"] = ss.fit_transform(Y)

# %% [markdown]
#  # Train Test Split
#
# Using train_test_split of sklearn will split data randomly so the sequence is lost.

# %%
def train_test_split(x,y,train_size):
    n = int(len(x)*train_size)
    trainx = x[:n]
    testx = x[n:]
    trainy=y[:n]
    testy=y[n:]
    return trainx,testx,trainy,testy

# %%
#Split train, validation, test set from X,Y to 80%, 10%, 10%

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.9)

# %%
X_train.shape,X_test.shape,X.shape
# Out:
# ((603, 1), (67, 1), (670, 1))

# %% [markdown]
# # Convert to Matrix

# %%
# convert into dataset matrix
def convertToMatrix(data, step):
    data = data.to_numpy()
    X, Y =[], []
    for i in range(len(data)-step):
        d=i+step  
        X.append(data[i:d,])
        Y.append(data[d,])
    return np.array(X), np.array(Y)

step=5

trainX,trainY =convertToMatrix(X_train,step)
testX,testY =convertToMatrix(X_test,step)
# validX,validY = convertToMatrix(X_valid,step)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
# validX = np.reshape(validX, (validX.shape[0], 1, validX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

trainX.shape,testX.shape #,validX.shape
# Out:
# ((598, 1, 5), (62, 1, 5))

# %% [markdown]
# # Modeling

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN


# SimpleRNN model
model = Sequential()
model.add(SimpleRNN(units=32, input_shape=(1,step), activation="relu"))
model.add(Dense(8, activation="relu")) 
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 32)                1216
#
#  dense_2 (Dense)             (None, 8)                 264
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,489
# Trainable params: 1,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
# we have 90% of data as train and if we take 11.11% from train, that will be equal to 10% of overall data as validation
model.fit(trainX,trainY, validation_split=0.111,#validation_data=(validX,validY),
          epochs=100, batch_size=16, verbose=2)
trainPredict = model.predict(trainX)
testPredict= model.predict(testX)
predicted=np.concatenate((trainPredict,testPredict),axis=0)
# Out:
# Epoch 1/100
# 34/34 - 3s - loss: 0.0637 - val_loss: 2.7792 - 3s/epoch - 75ms/step
# Epoch 2/100
# 34/34 - 0s - loss: 0.0213 - val_loss: 2.1879 - 127ms/epoch - 4ms/step
# Epoch 3/100
# 34/34 - 0s - loss: 0.0152 - val_loss: 1.4656 - 132ms/epoch - 4ms/step
# Epoch 4/100
# 34/34 - 0s - loss: 0.0101 - val_loss: 0.8645 - 130ms/epoch - 4ms/step
# Epoch 5/100
# 34/34 - 0s - loss: 0.0063 - val_loss: 0.4209 - 130ms/epoch - 4ms/step
# Epoch 6/100
# 34/34 - 0s - loss: 0.0039 - val_loss: 0.1595 - 127ms/epoch - 4ms/step
# Epoch 7/100
# 34/34 - 0s - loss: 0.0030 - val_loss: 0.0693 - 126ms/epoch - 4ms/step
# Epoch 8/100
# 34/34 - 0s - loss: 0.0025 - val_loss: 0.0763 - 125ms/epoch - 4ms/step
# Epoch 9/100
# 34/34 - 0s - loss: 0.0025 - val_loss: 0.0458 - 130ms/epoch - 4ms/step
# Epoch 10/100
# 34/34 - 0s - loss: 0.0023 - val_loss: 0.0431 - 133ms/epoch - 4ms/step
# Epoch 11/100
# 34/34 - 0s - loss: 0.0023 - val_loss: 0.0448 - 127ms/epoch - 4ms/step
# Epoch 12/100
# 34/34 - 0s - loss: 0.0023 - val_loss: 0.0422 - 126ms/epoch - 4ms/step
# Epoch 13/100
# 34/34 - 0s - loss: 0.0022 - val_loss: 0.0412 - 129ms/epoch - 4ms/step
# Epoch 14/100
# 34/34 - 0s - loss: 0.0022 - val_loss: 0.0407 - 135ms/epoch - 4ms/step
# Epoch 15/100
# 34/34 - 0s - loss: 0.0021 - val_loss: 0.0433 - 131ms/epoch - 4ms/step
# Epoch 16/100
# 34/34 - 0s - loss: 0.0021 - val_loss: 0.0425 - 129ms/epoch - 4ms/step
# Epoch 17/100
# 34/34 - 0s - loss: 0.0021 - val_loss: 0.0404 - 147ms/epoch - 4ms/step
# Epoch 18/100
# 34/34 - 0s - loss: 0.0020 - val_loss: 0.0399 - 137ms/epoch - 4ms/step
# Epoch 19/100
# 34/34 - 0s - loss: 0.0021 - val_loss: 0.0419 - 139ms/epoch - 4ms/step
# Epoch 20/100
# 34/34 - 0s - loss: 0.0020 - val_loss: 0.0379 - 132ms/epoch - 4ms/step
# Epoch 21/100
# 34/34 - 0s - loss: 0.0020 - val_loss: 0.0374 - 131ms/epoch - 4ms/step
# Epoch 22/100
# 34/34 - 0s - loss: 0.0020 - val_loss: 0.0367 - 130ms/epoch - 4ms/step
# Epoch 23/100
# 34/34 - 0s - loss: 0.0019 - val_loss: 0.0382 - 125ms/epoch - 4ms/step
# Epoch 24/100
# 34/34 - 0s - loss: 0.0019 - val_loss: 0.0362 - 131ms/epoch - 4ms/step
# Epoch 25/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0419 - 129ms/epoch - 4ms/step
# Epoch 26/100
# 34/34 - 0s - loss: 0.0019 - val_loss: 0.0562 - 133ms/epoch - 4ms/step
# Epoch 27/100
# 34/34 - 0s - loss: 0.0019 - val_loss: 0.0402 - 135ms/epoch - 4ms/step
# Epoch 28/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0344 - 149ms/epoch - 4ms/step
# Epoch 29/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0347 - 141ms/epoch - 4ms/step
# Epoch 30/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0336 - 132ms/epoch - 4ms/step
# Epoch 31/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0367 - 133ms/epoch - 4ms/step
# Epoch 32/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0435 - 133ms/epoch - 4ms/step
# Epoch 33/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0323 - 135ms/epoch - 4ms/step
# Epoch 34/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0333 - 126ms/epoch - 4ms/step
# Epoch 35/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0404 - 133ms/epoch - 4ms/step
# Epoch 36/100
# 34/34 - 0s - loss: 0.0017 - val_loss: 0.0392 - 130ms/epoch - 4ms/step
# Epoch 37/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0311 - 154ms/epoch - 5ms/step
# Epoch 38/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0574 - 130ms/epoch - 4ms/step
# Epoch 39/100
# 34/34 - 0s - loss: 0.0017 - val_loss: 0.0720 - 125ms/epoch - 4ms/step
# Epoch 40/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0309 - 126ms/epoch - 4ms/step
# Epoch 41/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0594 - 129ms/epoch - 4ms/step
# Epoch 42/100
# 34/34 - 0s - loss: 0.0017 - val_loss: 0.0421 - 132ms/epoch - 4ms/step
# Epoch 43/100
# 34/34 - 0s - loss: 0.0017 - val_loss: 0.0355 - 126ms/epoch - 4ms/step
# Epoch 44/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0344 - 129ms/epoch - 4ms/step
# Epoch 45/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0368 - 127ms/epoch - 4ms/step
# Epoch 46/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0318 - 150ms/epoch - 4ms/step
# Epoch 47/100
# 34/34 - 0s - loss: 0.0017 - val_loss: 0.0506 - 158ms/epoch - 5ms/step
# Epoch 48/100
# 34/34 - 0s - loss: 0.0017 - val_loss: 0.0888 - 135ms/epoch - 4ms/step
# Epoch 49/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0376 - 145ms/epoch - 4ms/step
# Epoch 50/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0391 - 149ms/epoch - 4ms/step
# Epoch 51/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0405 - 144ms/epoch - 4ms/step
# Epoch 52/100
# 34/34 - 0s - loss: 0.0018 - val_loss: 0.0456 - 147ms/epoch - 4ms/step
# Epoch 53/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0533 - 141ms/epoch - 4ms/step
# Epoch 54/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0365 - 125ms/epoch - 4ms/step
# Epoch 55/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0520 - 127ms/epoch - 4ms/step
# Epoch 56/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0444 - 126ms/epoch - 4ms/step
# Epoch 57/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0356 - 120ms/epoch - 4ms/step
# Epoch 58/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0345 - 128ms/epoch - 4ms/step
# Epoch 59/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0401 - 126ms/epoch - 4ms/step
# Epoch 60/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0828 - 122ms/epoch - 4ms/step
# Epoch 61/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0576 - 126ms/epoch - 4ms/step
# Epoch 62/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0473 - 135ms/epoch - 4ms/step
# Epoch 63/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0284 - 148ms/epoch - 4ms/step
# Epoch 64/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0288 - 145ms/epoch - 4ms/step
# Epoch 65/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0463 - 146ms/epoch - 4ms/step
# Epoch 66/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0401 - 145ms/epoch - 4ms/step
# Epoch 67/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0657 - 123ms/epoch - 4ms/step
# Epoch 68/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0325 - 146ms/epoch - 4ms/step
# Epoch 69/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0343 - 121ms/epoch - 4ms/step
# Epoch 70/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0490 - 126ms/epoch - 4ms/step
# Epoch 71/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0462 - 134ms/epoch - 4ms/step
# Epoch 72/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0822 - 127ms/epoch - 4ms/step
# Epoch 73/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0515 - 121ms/epoch - 4ms/step
# Epoch 74/100
# 34/34 - 0s - loss: 0.0016 - val_loss: 0.0504 - 117ms/epoch - 3ms/step
# Epoch 75/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0304 - 123ms/epoch - 4ms/step
# Epoch 76/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0354 - 125ms/epoch - 4ms/step
# Epoch 77/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0553 - 127ms/epoch - 4ms/step
# Epoch 78/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0645 - 128ms/epoch - 4ms/step
# Epoch 79/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0570 - 128ms/epoch - 4ms/step
# Epoch 80/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0372 - 129ms/epoch - 4ms/step
# Epoch 81/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0429 - 127ms/epoch - 4ms/step
# Epoch 82/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0319 - 130ms/epoch - 4ms/step
# Epoch 83/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0505 - 126ms/epoch - 4ms/step
# Epoch 84/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0680 - 127ms/epoch - 4ms/step
# Epoch 85/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0306 - 132ms/epoch - 4ms/step
# Epoch 86/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0285 - 126ms/epoch - 4ms/step
# Epoch 87/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.1419 - 164ms/epoch - 5ms/step
# Epoch 88/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0544 - 128ms/epoch - 4ms/step
# Epoch 89/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0436 - 127ms/epoch - 4ms/step
# Epoch 90/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0618 - 127ms/epoch - 4ms/step
# Epoch 91/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0399 - 131ms/epoch - 4ms/step
# Epoch 92/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0744 - 131ms/epoch - 4ms/step
# Epoch 93/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0365 - 128ms/epoch - 4ms/step
# Epoch 94/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.1099 - 128ms/epoch - 4ms/step
# Epoch 95/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0349 - 124ms/epoch - 4ms/step
# Epoch 96/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0580 - 126ms/epoch - 4ms/step
# Epoch 97/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0637 - 124ms/epoch - 4ms/step
# Epoch 98/100
# 34/34 - 0s - loss: 0.0015 - val_loss: 0.0803 - 126ms/epoch - 4ms/step
# Epoch 99/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0632 - 125ms/epoch - 4ms/step
# Epoch 100/100
# 34/34 - 0s - loss: 0.0014 - val_loss: 0.0781 - 128ms/epoch - 4ms/step
# 19/19 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 5ms/step

# %% [markdown]
# # Evaluate
#
# Smaller the better.

# %%
test_score = model.evaluate(testX, testPredict, verbose=0)
print(test_score)
# Out:
# 5.042561200275511e-15

# %% [markdown]
# # RMSE of Test

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(ss.inverse_transform(testX[:,:,0].flatten()), 
                   ss.inverse_transform(testPredict.flatten()), squared=False)
# Out:
# 32.86703339002852

# %% [markdown]
# # Predict Trend

# %%
test=pd.DataFrame()
test["pred"]=ss.inverse_transform(testPredict.flatten())
test["real"]=ss.inverse_transform(testX[:,:,0])
test["date"]=X_test.index[:-5]
test.iplot(kind="line", x="date")
# Out:
# <div>                            <div id="f12f2f14-de0e-45ff-80e5-de26883d6774" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("f12f2f14-de0e-45ff-80e5-de26883d6774")) {                    Plotly.newPlot(                        "f12f2f14-de0e-45ff-80e5-de26883d6774",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"pred","text":"","x":["2021-09-14","2021-09-15","2021-09-16","2021-09-20","2021-09-21","2021-09-22","2021-09-23","2021-09-26","2021-09-27","2021-09-28","2021-09-29","2021-09-30","2021-10-03","2021-10-04","2021-10-05","2021-10-06","2021-10-10","2021-10-11","2021-10-17","2021-10-18","2021-10-19","2021-10-20","2021-10-21","2021-10-24","2021-10-25","2021-10-26","2021-10-27","2021-10-28","2021-10-31","2021-11-01","2021-11-02","2021-11-03","2021-11-08","2021-11-09","2021-11-11","2021-11-14","2021-11-15","2021-11-16","2021-11-17","2021-11-18","2021-11-21","2021-11-22","2021-11-23","2021-11-24","2021-11-25","2021-11-28","2021-11-29","2021-11-30","2021-12-01","2021-12-02","2021-12-05","2021-12-06","2021-12-07","2021-12-08","2021-12-09","2021-12-12","2021-12-13","2021-12-14","2021-12-15","2021-12-16","2021-12-20","2021-12-21"],"y":[339.2720642089844,359.10137939453125,346.9342346191406,332.18011474609375,319.8178405761719,302.6263122558594,322.26629638671875,298.3841247558594,297.2923278808594,279.62030029296875,291.7232360839844,299.2236328125,296.19244384765625,295.1740417480469,290.8786926269531,281.9919738769531,269.3389587402344,293.2701416015625,283.4518127441406,293.8822937011719,311.70037841796875,338.5909423828125,323.3640441894531,328.95172119140625,343.7027893066406,335.1869201660156,341.9014892578125,328.1802062988281,324.9265441894531,311.4482421875,303.3618469238281,309.30914306640625,314.7968444824219,330.21905517578125,324.4055480957031,319.89508056640625,321.51007080078125,320.8629150390625,316.5908203125,322.1946105957031,322.676513671875,306.3719482421875,312.0205078125,312.5914611816406,315.6082458496094,302.5180358886719,293.7148132324219,300.8083801269531,287.8797912597656,283.8790588378906,273.6354675292969,259.5522155761719,243.10501098632812,261.5566711425781,272.4941711425781,263.69940185546875,253.4873504638672,268.91558837890625,287.7616271972656,281.56402587890625,279.8010559082031,263.9394226074219],"type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"real","text":"","x":["2021-09-14","2021-09-15","2021-09-16","2021-09-20","2021-09-21","2021-09-22","2021-09-23","2021-09-26","2021-09-27","2021-09-28","2021-09-29","2021-09-30","2021-10-03","2021-10-04","2021-10-05","2021-10-06","2021-10-10","2021-10-11","2021-10-17","2021-10-18","2021-10-19","2021-10-20","2021-10-21","2021-10-24","2021-10-25","2021-10-26","2021-10-27","2021-10-28","2021-10-31","2021-11-01","2021-11-02","2021-11-03","2021-11-08","2021-11-09","2021-11-11","2021-11-14","2021-11-15","2021-11-16","2021-11-17","2021-11-18","2021-11-21","2021-11-22","2021-11-23","2021-11-24","2021-11-25","2021-11-28","2021-11-29","2021-11-30","2021-12-01","2021-12-02","2021-12-05","2021-12-06","2021-12-07","2021-12-08","2021-12-09","2021-12-12","2021-12-13","2021-12-14","2021-12-15","2021-12-16","2021-12-20","2021-12-21"],"y":[405.54451417272924,400.639168349472,386.6238945687366,348.48232806544956,355.4899649558173,384.52160350162626,372.5085116895674,352.3865829043687,340.4736001907437,313.3440345151773,333.465963300376,315.44632558228767,301.4310518015523,289.4179599894934,298.4277788485376,310.4408706605965,308.43868869192,308.43868869192,304.5344338530009,290.41905097383165,272.39941325574335,299.62908802974346,295.72483319082437,301.4310518015523,331.4637813316996,363.49869283052317,349.4834190497878,353.4877829871408,372.5085116895674,359.49432889317023,364.4997838148614,354.18854667617757,341.2744729782143,327.25919919747895,314.2450164010818,321.4528714883171,330.26247215049364,348.38221 ...
