# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import cufflinks

cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Read Data

# %%
sanimads = pd.read_csv("SANIMA_2000-01-01_2021-12-31.csv", engine='python')
sanimads.head()
# Out:
#    S.N.        Date  Total Transactions  Total Traded Shares  \
# 0     1  2021-12-29                 169              40088.0
# 1     2  2021-12-28                 225              36901.0
# 2     3  2021-12-27                 311              63171.0
# 3     4  2021-12-26                 312              53556.0
# 4     5  2021-12-23                 267              37310.0
#
#    Total Traded Amount  Max. Price  Min. Price  Close Price
# 0           14203816.4       356.0       350.0        354.0
# 1           12875470.3       355.0       338.2        352.0
# 2           22589549.7       363.0       355.0        356.0
# 3           19125145.5       362.0       348.5        358.0
# 4           13066461.5       353.0       344.1        350.0

# %% [markdown]
# ## Sort Data in Ascending order

# %%
sanimads = sanimads.sort_values(by="Date")
sanimads
# Out:
#       S.N.        Date  Total Transactions  Total Traded Shares  \
# 2256  2257  2010-04-19                   8               1025.0
# 2255  2256  2010-04-20                  12               1150.0
# 2254  2255  2010-04-21                   3                150.0
# 2253  2254  2010-04-22                  11                593.0
# 2252  2253  2010-04-25                  18               2825.0
# ...    ...         ...                 ...                  ...
# 4        5  2021-12-23                 267              37310.0
# 3        4  2021-12-26                 312              53556.0
# 2        3  2021-12-27                 311              63171.0
# 1        2  2021-12-28                 225              36901.0
# 0        1  2021-12-29                 169              40088.0
#
#       Total Traded Amount  Max. Price  Min. Price  Close Price
# 2256             405750.0       400.0       390.0        390.0
# 2255             439525.0       385.0       379.0        384.0
# 2254              55850.0       377.0       370.0        370.0
# 2253             208378.0       365.0       342.0        359.0
# 2252             969420.0       366.0       338.0        338.0
# ...                   ...         ...         ...          ...
# 4              13066461.5       353.0       344.1        350.0
# 3              19125145.5       362.0       348.5        358.0
# 2              22589549.7       363.0       355.0        356.0
# 1              12875470.3       355.0       338.2        352.0
# 0              14203816.4       356.0       350.0        354.0
#
# [2257 rows x 8 columns]

# %% [markdown]
# ## Handle Missing NAs

# %%
sanimads= sanimads.dropna()
sanimads.tail()
# Out:
#    S.N.        Date  Total Transactions  Total Traded Shares  \
# 4     5  2021-12-23                 267              37310.0
# 3     4  2021-12-26                 312              53556.0
# 2     3  2021-12-27                 311              63171.0
# 1     2  2021-12-28                 225              36901.0
# 0     1  2021-12-29                 169              40088.0
#
#    Total Traded Amount  Max. Price  Min. Price  Close Price
# 4           13066461.5       353.0       344.1        350.0
# 3           19125145.5       362.0       348.5        358.0
# 2           22589549.7       363.0       355.0        356.0
# 1           12875470.3       355.0       338.2        352.0
# 0           14203816.4       356.0       350.0        354.0

# %% [markdown]
# ## Plot Trend

# %%
sanimads.iplot(kind="line",x="Date",y="Close Price",xTitle="Date", yTitle="Close Price", title="SANIMA Trend")
# Out:
# <div>                            <div id="d0c7fdcd-c0e8-4dc6-b790-fe049accfccb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("d0c7fdcd-c0e8-4dc6-b790-fe049accfccb")) {                    Plotly.newPlot(                        "d0c7fdcd-c0e8-4dc6-b790-fe049accfccb",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Close Price","text":"","x":["2010-04-19","2010-04-20","2010-04-21","2010-04-22","2010-04-25","2010-04-26","2010-04-27","2010-04-28","2010-04-29","2010-05-09","2010-05-11","2010-05-12","2010-05-13","2010-05-16","2010-05-17","2010-05-18","2010-05-19","2010-05-20","2010-05-23","2010-05-24","2010-05-25","2010-05-26","2010-05-30","2010-05-31","2010-06-01","2010-06-02","2010-06-03","2010-06-06","2010-06-07","2010-06-08","2010-06-09","2010-06-10","2012-02-27","2012-02-29","2012-03-06","2012-03-13","2012-03-14","2012-03-15","2012-03-19","2012-03-20","2012-03-21","2012-03-25","2012-03-26","2012-03-27","2012-03-28","2012-03-29","2012-04-01","2012-04-02","2012-04-03","2012-04-04","2012-04-05","2012-04-08","2012-04-09","2012-04-10","2012-04-11","2012-04-12","2012-04-15","2012-04-16","2012-04-17","2012-04-18","2012-04-19","2012-04-22","2012-04-24","2012-04-25","2012-04-26","2012-04-29","2012-04-30","2012-05-02","2012-05-03","2012-05-07","2012-05-08","2012-05-09","2012-05-10","2012-05-13","2012-05-14","2012-05-15","2012-05-16","2012-05-17","2012-05-20","2012-05-21","2012-05-22","2012-05-23","2012-05-24","2012-05-27","2012-05-30","2012-05-31","2012-06-03","2012-06-04","2012-06-05","2012-06-06","2012-06-07","2012-06-10","2012-06-11","2012-06-12","2012-06-13","2012-06-14","2012-06-17","2012-06-18","2012-06-19","2012-06-20","2012-06-21","2012-06-25","2012-06-26","2012-06-27","2012-06-28","2012-07-01","2012-07-02","2012-07-03","2012-07-04","2012-07-05","2012-07-08","2012-07-09","2012-07-10","2012-07-11","2012-07-12","2012-07-15","2012-07-16","2012-07-17","2012-07-18","2012-07-19","2012-07-22","2012-07-23","2012-07-24","2012-07-25","2012-07-26","2012-07-29","2012-07-30","2012-07-31","2012-08-01","2012-08-05","2012-08-06","2012-08-07","2012-08-08","2012-08-12","2012-08-13","2012-08-14","2012-08-15","2012-08-16","2012-08-19","2012-08-21","2012-08-22","2012-08-23","2012-08-26","2012-08-27","2012-08-28","2012-08-29","2012-08-30","2012-09-02","2012-09-03","2012-09-04","2012-09-05","2012-09-06","2012-09-09","2012-09-10","2012-09-11","2012-09-12","2012-09-13","2012-09-16","2012-09-17","2012-09-18","2012-09-19","2012-09-20","2012-09-23","2012-09-24","2012-09-25","2012-09-26","2012-09-27","2012-09-30","2012-10-01","2012-10-02","2012-10-03","2012-10-04","2012-10-07","2012-10-08","2012-10-09","2012-10-10","2012-10-11","2012-10-14","2012-10-15","2012-10-17","2012-10-18","2012-10-30","2012-10-31","2012-11-01","2012-11-04","2012-11-05","2012-11-06","2012-11-07","2012-11-08","2012-11-11","2012-11-12","2012-11-18","2012-11-20","2012-11-21","2012-11-22","2012-11-25","2012-11-26","2012-11-27","2012-11-28","2012-11-29","2012-12-02","2012-12-03","2012-12-04","2012-12-05","2012-12-06","2012-12-09","2012-12-10","2012-12-11","2012-12-12","2012-12-13","2012-12-16","2012-12-17","2012-12-18","2012-12-19","2012-12-20","2012-12-23","2012-12-24","2012-12-26","2012-12-27","2012-12-31","2013-01-01","2013-01-02","2013-01-03","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-13","2013-01-15","2013-01-16","2013-01-17","2013-01-20","2013-01-21","2013-01-22","2013-01-23","2013-01-24","2013-01-27","2013-01-28","2013-01-30","2013-01-31","2013-02-03","2013-02-04","2013-02-05","2013-02-06","2013-02-07","2013-02-10","2013-02-12","2013-02-13","2013-02-14","2013-02-17","2013-02-19","2013-02-20","2013-02-21","2013-02-24","2013-02-25","2013-02-26","2013-02-27","2013-02-28","2013-03-03","2013-03-04","2013-03-05","2013-03-07","2013-03-11","2013-03-13","2013-03-14","2013-03-17","2013-03-18","2013-03-19","2013-03-21","2013-03-24","2013-03-25","2013-03-27","2013-03-28","2013-04-01","2013- ...

# %% [markdown]
# ## Next Price

# %%
sanimads['Next Price'] = sanimads.shift(-1)['Close Price']

# %% [markdown]
# ## Rename Columns

# %%
sanimads.rename(columns = {'S.N.':'SN','Total Transactions':'TTrans', 'Total Traded Shares':'TTS',
                              'Total Traded Amount':'TTA','Close Price':'ClosePrice','Next Price':'NextPrice',
                     'Max. Price':'MaxPrice','Min. Price':'MinPrice'}, inplace = True)

# %% [markdown]
# ## Prepare Features

# %%
features = ['ClosePrice',"Date"]
outFeature = ['NextPrice',"Date"]

# %%
# take close price as feature and next price as out feature
X, Y = sanimads[features], sanimads[outFeature] 
X.set_index("Date", inplace=True)
Y.set_index("Date", inplace=True)

# %% [markdown]
# ## Normalize Data

# %%
#Normalize data using standard scalar.
ss = StandardScaler()
# print(type(X))
# print(X)
X["ClosePrice"] = ss.fit_transform(X)
Y["NextPrice"] = ss.fit_transform(Y)
# print(type(Xs))
# print(Xs)
# print(Ys)

# %% [markdown]
# ## Train Test Split
#
# Using train_test_split of sklearn will split data randomly so the sequence is lost.

# %%
def train_test_split(x,y,train_size):
    n = int(len(x)*train_size)
    trainx = x[:n]
    testx = x[n:]
    trainy=y[:n]
    testy=y[n:]
    return trainx,testx,trainy,testy

# %%
#Split train, validation, test set from X,Y to 80%, 10%, 10%

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.9)

# X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, train_size=0.5)

# print(X_train.shape)
# print(X_valid.shape)
# print(X_test.shape)

# print(Y_train.shape)
# print(Y_valid.shape)
# print(Y_test.shape)

# %%
X_train.shape,X_test.shape,X.shape
# Out:
# ((2031, 1), (226, 1), (2257, 1))

# %% [markdown]
# ## Convert to Matrix
# https://www.datatechnotes.com/2018/12/rnn-example-with-keras-simplernn-in.html

# %%
# convert into dataset matrix
def convertToMatrix(data, step):
    data = data.to_numpy()
    X, Y =[], []
    for i in range(len(data)-step):
        d=i+step  
        X.append(data[i:d,])
        Y.append(data[d,])
    return np.array(X), np.array(Y)

step=5

trainX,trainY =convertToMatrix(X_train,step)
testX,testY =convertToMatrix(X_test,step)
# validX,validY = convertToMatrix(X_valid,step)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
# validX = np.reshape(validX, (validX.shape[0], 1, validX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

trainX.shape,testX.shape #,validX.shape
# Out:
# ((2026, 1, 5), (221, 1, 5))

# %% [markdown]
# ## Modeling

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN


# SimpleRNN model
model = Sequential()
model.add(SimpleRNN(units=32, input_shape=(1,step), activation="relu"))
model.add(Dense(8, activation="relu")) 
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_12 (SimpleRNN)   (None, 32)                1216
#
#  dense_24 (Dense)            (None, 8)                 264
#
#  dense_25 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 1,489
# Trainable params: 1,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
# we have 90% of data as train and if we take 11.11% from train, that will be equal to 10% of overall data as validation
model.fit(trainX,trainY, validation_split=0.111,#validation_data=(validX,validY),
          epochs=100, batch_size=16, verbose=2)
trainPredict = model.predict(trainX)
testPredict= model.predict(testX)
predicted=np.concatenate((trainPredict,testPredict),axis=0)
# Out:
# Epoch 1/100
# 113/113 - 0s - loss: 0.0159 - val_loss: 0.0021 - 201ms/epoch - 2ms/step
# Epoch 2/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0025 - 174ms/epoch - 2ms/step
# Epoch 3/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0023 - 171ms/epoch - 2ms/step
# Epoch 4/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 174ms/epoch - 2ms/step
# Epoch 5/100
# 113/113 - 0s - loss: 0.0159 - val_loss: 0.0022 - 176ms/epoch - 2ms/step
# Epoch 6/100
# 113/113 - 0s - loss: 0.0159 - val_loss: 0.0034 - 215ms/epoch - 2ms/step
# Epoch 7/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0021 - 175ms/epoch - 2ms/step
# Epoch 8/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0022 - 192ms/epoch - 2ms/step
# Epoch 9/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0024 - 170ms/epoch - 2ms/step
# Epoch 10/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0029 - 174ms/epoch - 2ms/step
# Epoch 11/100
# 113/113 - 0s - loss: 0.0159 - val_loss: 0.0022 - 177ms/epoch - 2ms/step
# Epoch 12/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0031 - 187ms/epoch - 2ms/step
# Epoch 13/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0021 - 170ms/epoch - 2ms/step
# Epoch 14/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0023 - 172ms/epoch - 2ms/step
# Epoch 15/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0028 - 265ms/epoch - 2ms/step
# Epoch 16/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 167ms/epoch - 1ms/step
# Epoch 17/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0021 - 174ms/epoch - 2ms/step
# Epoch 18/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0022 - 172ms/epoch - 2ms/step
# Epoch 19/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0022 - 175ms/epoch - 2ms/step
# Epoch 20/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0021 - 172ms/epoch - 2ms/step
# Epoch 21/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0022 - 190ms/epoch - 2ms/step
# Epoch 22/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0026 - 169ms/epoch - 1ms/step
# Epoch 23/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0033 - 171ms/epoch - 2ms/step
# Epoch 24/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0023 - 176ms/epoch - 2ms/step
# Epoch 25/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0022 - 170ms/epoch - 2ms/step
# Epoch 26/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 176ms/epoch - 2ms/step
# Epoch 27/100
# 113/113 - 0s - loss: 0.0159 - val_loss: 0.0025 - 174ms/epoch - 2ms/step
# Epoch 28/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0031 - 173ms/epoch - 2ms/step
# Epoch 29/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0022 - 171ms/epoch - 2ms/step
# Epoch 30/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0025 - 175ms/epoch - 2ms/step
# Epoch 31/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0022 - 175ms/epoch - 2ms/step
# Epoch 32/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0022 - 176ms/epoch - 2ms/step
# Epoch 33/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0021 - 177ms/epoch - 2ms/step
# Epoch 34/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 188ms/epoch - 2ms/step
# Epoch 35/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 188ms/epoch - 2ms/step
# Epoch 36/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 181ms/epoch - 2ms/step
# Epoch 37/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 174ms/epoch - 2ms/step
# Epoch 38/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 211ms/epoch - 2ms/step
# Epoch 39/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0035 - 218ms/epoch - 2ms/step
# Epoch 40/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0022 - 182ms/epoch - 2ms/step
# Epoch 41/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0036 - 171ms/epoch - 2ms/step
# Epoch 42/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0023 - 170ms/epoch - 2ms/step
# Epoch 43/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0024 - 171ms/epoch - 2ms/step
# Epoch 44/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0023 - 168ms/epoch - 1ms/step
# Epoch 45/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0022 - 172ms/epoch - 2ms/step
# Epoch 46/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0027 - 170ms/epoch - 2ms/step
# Epoch 47/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0022 - 167ms/epoch - 1ms/step
# Epoch 48/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0038 - 169ms/epoch - 1ms/step
# Epoch 49/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 168ms/epoch - 1ms/step
# Epoch 50/100
# 113/113 - 0s - loss: 0.0159 - val_loss: 0.0023 - 170ms/epoch - 2ms/step
# Epoch 51/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0045 - 172ms/epoch - 2ms/step
# Epoch 52/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0022 - 168ms/epoch - 1ms/step
# Epoch 53/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0031 - 173ms/epoch - 2ms/step
# Epoch 54/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0022 - 171ms/epoch - 2ms/step
# Epoch 55/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0022 - 169ms/epoch - 1ms/step
# Epoch 56/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0024 - 173ms/epoch - 2ms/step
# Epoch 57/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0022 - 169ms/epoch - 1ms/step
# Epoch 58/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 173ms/epoch - 2ms/step
# Epoch 59/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0025 - 170ms/epoch - 2ms/step
# Epoch 60/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0022 - 183ms/epoch - 2ms/step
# Epoch 61/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0024 - 182ms/epoch - 2ms/step
# Epoch 62/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 177ms/epoch - 2ms/step
# Epoch 63/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 189ms/epoch - 2ms/step
# Epoch 64/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0025 - 203ms/epoch - 2ms/step
# Epoch 65/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0023 - 197ms/epoch - 2ms/step
# Epoch 66/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 179ms/epoch - 2ms/step
# Epoch 67/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0037 - 185ms/epoch - 2ms/step
# Epoch 68/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0028 - 183ms/epoch - 2ms/step
# Epoch 69/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0024 - 180ms/epoch - 2ms/step
# Epoch 70/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0022 - 177ms/epoch - 2ms/step
# Epoch 71/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0022 - 196ms/epoch - 2ms/step
# Epoch 72/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0023 - 168ms/epoch - 1ms/step
# Epoch 73/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0024 - 169ms/epoch - 1ms/step
# Epoch 74/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0028 - 175ms/epoch - 2ms/step
# Epoch 75/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 170ms/epoch - 2ms/step
# Epoch 76/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0023 - 177ms/epoch - 2ms/step
# Epoch 77/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0026 - 173ms/epoch - 2ms/step
# Epoch 78/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0024 - 168ms/epoch - 1ms/step
# Epoch 79/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0027 - 178ms/epoch - 2ms/step
# Epoch 80/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0026 - 226ms/epoch - 2ms/step
# Epoch 81/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0027 - 176ms/epoch - 2ms/step
# Epoch 82/100
# 113/113 - 0s - loss: 0.0153 - val_loss: 0.0024 - 173ms/epoch - 2ms/step
# Epoch 83/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0026 - 170ms/epoch - 2ms/step
# Epoch 84/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0023 - 171ms/epoch - 2ms/step
# Epoch 85/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0024 - 175ms/epoch - 2ms/step
# Epoch 86/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0025 - 252ms/epoch - 2ms/step
# Epoch 87/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0023 - 174ms/epoch - 2ms/step
# Epoch 88/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0044 - 172ms/epoch - 2ms/step
# Epoch 89/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0034 - 176ms/epoch - 2ms/step
# Epoch 90/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 212ms/epoch - 2ms/step
# Epoch 91/100
# 113/113 - 0s - loss: 0.0158 - val_loss: 0.0024 - 216ms/epoch - 2ms/step
# Epoch 92/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0026 - 168ms/epoch - 1ms/step
# Epoch 93/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0025 - 197ms/epoch - 2ms/step
# Epoch 94/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0023 - 175ms/epoch - 2ms/step
# Epoch 95/100
# 113/113 - 0s - loss: 0.0155 - val_loss: 0.0031 - 168ms/epoch - 1ms/step
# Epoch 96/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0023 - 211ms/epoch - 2ms/step
# Epoch 97/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0028 - 237ms/epoch - 2ms/step
# Epoch 98/100
# 113/113 - 0s - loss: 0.0154 - val_loss: 0.0025 - 167ms/epoch - 1ms/step
# Epoch 99/100
# 113/113 - 0s - loss: 0.0156 - val_loss: 0.0025 - 167ms/epoch - 1ms/step
# Epoch 100/100
# 113/113 - 0s - loss: 0.0157 - val_loss: 0.0032 - 169ms/epoch - 1ms/step
# 64/64 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Evaluate
#
# Smaller the better.

# %%
test_score = model.evaluate(testX, testPredict, verbose=0)
print(test_score)
# Out:
# 1.031100829989185e-15

# %%
# testPredict

# %% [markdown]
# ## RMSE of Test

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(ss.inverse_transform(testX[:,:,0].flatten()), 
                   ss.inverse_transform(testPredict.flatten()), squared=False)
# Out:
# 20.77213452547952

# %% [markdown]
# ## Predict Trend

# %%
# testPredict

# %%
# testX[:,:,0]
# plt.plot(X_test.index[5:],testX[:,:,0])
# plt.plot(X_test.index[5:],testPredict.flatten())
# plt.legend(["True Data", "Predicted"])
# plt.show()

# %%
testX.shape
# Out:
# (221, 1, 5)

# %%
test=pd.DataFrame()
test["pred"]=ss.inverse_transform(testPredict.flatten())
test["real"]=ss.inverse_transform(testX[:,:,0])
test["date"]=X_test.index[:-5]
test.iplot(kind="line", x="date")
# Out:
# <div>                            <div id="7238d6e9-f9a7-40a7-9a7e-d2911fafeb2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("7238d6e9-f9a7-40a7-9a7e-d2911fafeb2c")) {                    Plotly.newPlot(                        "7238d6e9-f9a7-40a7-9a7e-d2911fafeb2c",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"pred","text":"","x":["2021-01-21","2021-01-24","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-31","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-07","2021-02-08","2021-02-09","2021-02-10","2021-02-11","2021-02-14","2021-02-15","2021-02-16","2021-02-17","2021-02-18","2021-02-21","2021-02-22","2021-02-23","2021-02-24","2021-02-25","2021-02-28","2021-03-01","2021-03-02","2021-03-03","2021-03-04","2021-03-07","2021-03-09","2021-03-10","2021-03-14","2021-03-15","2021-03-16","2021-03-17","2021-03-18","2021-03-21","2021-03-22","2021-03-23","2021-03-24","2021-03-25","2021-03-29","2021-03-30","2021-03-31","2021-04-01","2021-04-04","2021-04-05","2021-04-06","2021-04-07","2021-04-08","2021-04-12","2021-04-13","2021-04-15","2021-04-18","2021-04-19","2021-04-20","2021-04-21","2021-04-22","2021-04-25","2021-04-26","2021-04-27","2021-04-28","2021-04-29","2021-05-02","2021-05-03","2021-05-04","2021-05-05","2021-05-06","2021-05-09","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-16","2021-05-17","2021-05-18","2021-05-19","2021-05-20","2021-05-23","2021-05-24","2021-05-25","2021-05-27","2021-05-30","2021-05-31","2021-06-01","2021-06-02","2021-06-03","2021-06-06","2021-06-07","2021-06-08","2021-06-09","2021-06-10","2021-06-13","2021-06-14","2021-06-15","2021-06-16","2021-06-17","2021-06-20","2021-06-21","2021-06-22","2021-06-23","2021-06-24","2021-06-27","2021-06-28","2021-06-29","2021-06-30","2021-07-01","2021-07-04","2021-07-05","2021-07-06","2021-07-07","2021-07-08","2021-07-11","2021-07-12","2021-07-13","2021-07-14","2021-07-15","2021-07-18","2021-07-19","2021-07-20","2021-07-22","2021-07-25","2021-07-26","2021-07-27","2021-07-28","2021-07-29","2021-08-01","2021-08-02","2021-08-03","2021-08-04","2021-08-05","2021-08-08","2021-08-09","2021-08-10","2021-08-11","2021-08-12","2021-08-15","2021-08-16","2021-08-17","2021-08-18","2021-08-19","2021-08-24","2021-08-25","2021-08-26","2021-08-29","2021-08-31","2021-09-01","2021-09-02","2021-09-05","2021-09-06","2021-09-07","2021-09-08","2021-09-09","2021-09-12","2021-09-13","2021-09-14","2021-09-15","2021-09-16","2021-09-20","2021-09-21","2021-09-22","2021-09-23","2021-09-26","2021-09-27","2021-09-28","2021-09-29","2021-09-30","2021-10-03","2021-10-04","2021-10-05","2021-10-06","2021-10-10","2021-10-11","2021-10-17","2021-10-18","2021-10-19","2021-10-20","2021-10-21","2021-10-24","2021-10-25","2021-10-26","2021-10-27","2021-10-28","2021-10-31","2021-11-01","2021-11-02","2021-11-03","2021-11-08","2021-11-09","2021-11-11","2021-11-14","2021-11-15","2021-11-16","2021-11-17","2021-11-18","2021-11-21","2021-11-22","2021-11-23","2021-11-24","2021-11-25","2021-11-28","2021-11-29","2021-11-30","2021-12-01","2021-12-02","2021-12-05","2021-12-06","2021-12-07","2021-12-08","2021-12-09","2021-12-12","2021-12-13","2021-12-14","2021-12-15","2021-12-16","2021-12-20","2021-12-21","2021-12-22"],"y":[347.6022033691406,339.3371276855469,333.6849670410156,337.5147399902344,345.2781677246094,344.0772705078125,353.8744201660156,352.7220764160156,376.9580993652344,370.4773864746094,369.4148254394531,369.6167297363281,361.43212890625,375.77911376953125,385.0168762207031,389.3378601074219,399.4356384277344,388.85858154296875,377.3025207519531,375.82330322265625,377.5584716796875,370.10455322265625,359.7187805175781,365.7406311035156,349.8473815917969,360.2607421875,368.68743896484375,357.71099853515625,355.354248046875,355.5818786621094,346.4862060546875,346.1086730957031,348.6010437011719,351.54864501953125,355.58148193359375,360.61993408203125,353.9564208984375,351.4220886230469,361.29864 ...

# %% [markdown]
# ## Train Trend

# %%
train=pd.DataFrame()
train["pred"]=ss.inverse_transform(trainPredict.flatten())
train["real"]=ss.inverse_transform(trainX[:,:,0])
train["date"]=X_train.index[:-5]
train.iplot(kind="line", x="date")
# Out:
# <div>                            <div id="c705ce6f-2c4c-4c6a-8be9-0e4f21650911" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("c705ce6f-2c4c-4c6a-8be9-0e4f21650911")) {                    Plotly.newPlot(                        "c705ce6f-2c4c-4c6a-8be9-0e4f21650911",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"pred","text":"","x":["2010-04-19","2010-04-20","2010-04-21","2010-04-22","2010-04-25","2010-04-26","2010-04-27","2010-04-28","2010-04-29","2010-05-09","2010-05-11","2010-05-12","2010-05-13","2010-05-16","2010-05-17","2010-05-18","2010-05-19","2010-05-20","2010-05-23","2010-05-24","2010-05-25","2010-05-26","2010-05-30","2010-05-31","2010-06-01","2010-06-02","2010-06-03","2010-06-06","2010-06-07","2010-06-08","2010-06-09","2010-06-10","2012-02-27","2012-02-29","2012-03-06","2012-03-13","2012-03-14","2012-03-15","2012-03-19","2012-03-20","2012-03-21","2012-03-25","2012-03-26","2012-03-27","2012-03-28","2012-03-29","2012-04-01","2012-04-02","2012-04-03","2012-04-04","2012-04-05","2012-04-08","2012-04-09","2012-04-10","2012-04-11","2012-04-12","2012-04-15","2012-04-16","2012-04-17","2012-04-18","2012-04-19","2012-04-22","2012-04-24","2012-04-25","2012-04-26","2012-04-29","2012-04-30","2012-05-02","2012-05-03","2012-05-07","2012-05-08","2012-05-09","2012-05-10","2012-05-13","2012-05-14","2012-05-15","2012-05-16","2012-05-17","2012-05-20","2012-05-21","2012-05-22","2012-05-23","2012-05-24","2012-05-27","2012-05-30","2012-05-31","2012-06-03","2012-06-04","2012-06-05","2012-06-06","2012-06-07","2012-06-10","2012-06-11","2012-06-12","2012-06-13","2012-06-14","2012-06-17","2012-06-18","2012-06-19","2012-06-20","2012-06-21","2012-06-25","2012-06-26","2012-06-27","2012-06-28","2012-07-01","2012-07-02","2012-07-03","2012-07-04","2012-07-05","2012-07-08","2012-07-09","2012-07-10","2012-07-11","2012-07-12","2012-07-15","2012-07-16","2012-07-17","2012-07-18","2012-07-19","2012-07-22","2012-07-23","2012-07-24","2012-07-25","2012-07-26","2012-07-29","2012-07-30","2012-07-31","2012-08-01","2012-08-05","2012-08-06","2012-08-07","2012-08-08","2012-08-12","2012-08-13","2012-08-14","2012-08-15","2012-08-16","2012-08-19","2012-08-21","2012-08-22","2012-08-23","2012-08-26","2012-08-27","2012-08-28","2012-08-29","2012-08-30","2012-09-02","2012-09-03","2012-09-04","2012-09-05","2012-09-06","2012-09-09","2012-09-10","2012-09-11","2012-09-12","2012-09-13","2012-09-16","2012-09-17","2012-09-18","2012-09-19","2012-09-20","2012-09-23","2012-09-24","2012-09-25","2012-09-26","2012-09-27","2012-09-30","2012-10-01","2012-10-02","2012-10-03","2012-10-04","2012-10-07","2012-10-08","2012-10-09","2012-10-10","2012-10-11","2012-10-14","2012-10-15","2012-10-17","2012-10-18","2012-10-30","2012-10-31","2012-11-01","2012-11-04","2012-11-05","2012-11-06","2012-11-07","2012-11-08","2012-11-11","2012-11-12","2012-11-18","2012-11-20","2012-11-21","2012-11-22","2012-11-25","2012-11-26","2012-11-27","2012-11-28","2012-11-29","2012-12-02","2012-12-03","2012-12-04","2012-12-05","2012-12-06","2012-12-09","2012-12-10","2012-12-11","2012-12-12","2012-12-13","2012-12-16","2012-12-17","2012-12-18","2012-12-19","2012-12-20","2012-12-23","2012-12-24","2012-12-26","2012-12-27","2012-12-31","2013-01-01","2013-01-02","2013-01-03","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-13","2013-01-15","2013-01-16","2013-01-17","2013-01-20","2013-01-21","2013-01-22","2013-01-23","2013-01-24","2013-01-27","2013-01-28","2013-01-30","2013-01-31","2013-02-03","2013-02-04","2013-02-05","2013-02-06","2013-02-07","2013-02-10","2013-02-12","2013-02-13","2013-02-14","2013-02-17","2013-02-19","2013-02-20","2013-02-21","2013-02-24","2013-02-25","2013-02-26","2013-02-27","2013-02-28","2013-03-03","2013-03-04","2013-03-05","2013-03-07","2013-03-11","2013-03-13","2013-03-14","2013-03-17","2013-03-18","2013-03-19","2013-03-21","2013-03-24","2013-03-25","2013-03-27","2013-03-28","2013-04-01","2013-04-03", ...
