# %%
This is a test text
# Out:
#   File "<ipython-input-1-f9cbdb6b7a88>", line 1
#     This is a test text
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# This

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# # New Section
